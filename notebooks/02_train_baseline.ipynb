# %% [markdown]
# # 02 — Train baseline (Stages D–E)
#
# Frozen-encoder plane-aware model with gold + weak report supervision and optional symbolic features/constraints. Writes OOF predictions and updates the ASRA ledger.

# %%
import json
import sys
from pathlib import Path

ROOT = Path.cwd()
if not (ROOT / "src").exists():
    ROOT = ROOT.parent
sys.path.insert(0, str(ROOT))

from src.train import run_training
from src.utils import load_config

cfg = load_config(ROOT / "configs" / "submission_001.yaml")
# For a smoke run on a laptop without full data, use quick_sanity=True after mounting a tiny subset.
report = run_training(cfg, quick_sanity=False)
print(json.dumps(report, indent=2, default=str))
